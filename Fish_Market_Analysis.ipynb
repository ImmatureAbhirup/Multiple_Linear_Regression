# %% [markdown]
# <a href="https://colab.research.google.com/github/ImmatureAbhirup/Multiple_Linear_Regression/blob/main/Fish_Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Multple Linear Regression &**
#
# # **Exploratory Data Analysis on Fish Market Analysis**

# %% [markdown]
# ## **Table of Contents**
#
# 1. [About the Dataset](#scrollTo=Xf6oeEAzmkGP)
#
# 2. [Importing Packages](#scrollTo=STbq-JmSNHTe)
#
# 3. [Mounting the drive](#scrollTo=2dzmb7goT3oI)

# %% [markdown]
# ## 1. **About the Dataset** :
#
# This is a Multiple Linear Dataset Problem. I have taken the dataset from Kaggle website. I have inserted the dataset's link below. This project is about Fish Market Analysis.
#
#
# The dataset consists 7 columns and 159 rows. You will get to know more about the dataset as you will go proceed further!
#
# Here is the link of the dataset : https://www.kaggle.com/aungpyaeap/fish-market/
#
# You can download the dataset from there.

# %% [markdown]
# ![R.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. **Importing Packages :**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 3. **Mounting the drive :**

# %%
from google.colab import drive
drive.mount("/content/drive") #This code will help us to connect our drive with google collab
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 4. **Reading the dataset :**

# %%
fish = pd.read_csv("/content/drive/MyDrive/Data Scince Tutorial/Supervised Learning/Regression Analysis/Multiple Linear Regression/Fish market/Fish.csv")

# %% [markdown]
# ## 5. **Understanding the Dataset :**

# %% [markdown]
# ### 5.1 **Head :**

# %%
fish.head()                                 #This will print first 5 rows of our dataset
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# ### 5.2 **Tail :**

# %%
fish.tail()                                         #This will print last 5 rows of our dataset
# Out:
#     Species  Weight  Length1  Length2  Length3  Height   Width
# 154   Smelt    12.2     11.5     12.2     13.4  2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5  2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8  2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2  2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2  2.9322  1.8792

# %% [markdown]
# ### 5.3 **Info :**

# %%
fish.info()    #This will give us total columns, rows Column names, data types and Non-null value counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# *As you see, this dataset doesn't has any null values. So, we don't have to perform any missing value techniques here!*

# %% [markdown]
# ### 5.4 **Shape :**

# %%
fish.shape #This will print total columns and rows.
# Out:
# (159, 7)

# %% [markdown]
# *This dataset's shape is*  **(159*7)**

# %% [markdown]
# ### 5.5 **Columns :**

# %%
fish.columns  #This will print all column names
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %% [markdown]
# ### 5.6 **Statistics :**

# %%
fish.describe()   #This will print all important statistics about the dataset
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %% [markdown]
# ### 5.7 **Histogram :**

# %%
fish.hist(bins=15, figsize =(10,15)) #This will create histograms for all continuous variables
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf8d60aad0>,
# ...
#       dtype=object)

# %%
#fish['logarithm_base2'] = np.log2(fish['Weight'])

# %%
np.seterr(divide = 'ignore')
fish['weight_logarithm_base2'] = np.where(fish['Weight']>0, np.log(fish['Weight']), 0)

# %%
fish.head()
# Out:
#   Species  Weight  Length1  ...   Height   Width  weight_logarithm_base2
# 0   Bream   242.0     23.2  ...  11.5200  4.0200                5.488938
# 1   Bream   290.0     24.0  ...  12.4800  4.3056                5.669881
# 2   Bream   340.0     23.9  ...  12.3778  4.6961                5.828946
# 3   Bream   363.0     26.3  ...  12.7300  4.4555                5.894403
# 4   Bream   430.0     26.5  ...  12.4440  5.1340                6.063785
#
# [5 rows x 8 columns]

# %%
fish.drop("Weight", axis=1, inplace= True)

# %% [markdown]
# ### 5.8 **PairPlot :**

# %%
sns.pairplot(data=fish.drop(["Length2","Length1"] , axis = 1)) 
#This will create all important graphs with each variables
#I have drop 3 columns here, because it's becoming complex to handle

# %%
sns.pairplot(data=fish.drop(["Length3","Height", "Width"] , axis = 1))

# %% [markdown]
# ### 5.9 **Analyzing the Category Fields :**

# %% [markdown]
# ***We have only 1 category fields. That is "Species" columns. Let's see what this column is saying***

# %%
print(fish["Species"].unique()) #This will give us all unique values present in the Species column
# Out:
# ['Bream' 'Roach' 'Whitefish' 'Parkki' 'Perch' 'Pike' 'Smelt']

# %%
fish_species = fish["Species"].value_counts()
fish_species
#This will print value of each sub categories
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
sns.set_style("ticks")
sns.countplot(x="Species", data=fish)
#This will create a bar graph on Species based on their counts

# %% [markdown]
# ### 5.10 **Box Plots :**

# %% [markdown]
# ***This will help us to understand how values are distributed. What is their mean, quartiles, outliers and many more things!***

# %% [markdown]
# ### 1. **Species and Weights**

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Species',y='weight_logarithm_base2',data=fish,palette='summer')

# %%
sns.barplot(x="Species", 
            y= "weight_logarithm_base2",
            data = fish,
            estimator = sum)

# %% [markdown]
# ### 2. **Species vs Length1**

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Species',y='Length1',data=fish,palette='summer')

# %%
sns.barplot(x="Species",
            y = 'Length1',
            data=fish,
            estimator = sum)

# %% [markdown]
# ### 3. **Species vs Length2**

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Species',y='Length2',data=fish,palette='summer')

# %%
sns.barplot(x="Species",
            y = 'Length2',
            data=fish,
            estimator = sum)

# %% [markdown]
# ### 4. **Species vs Length3**

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Species',y='Length3',data=fish,palette='summer')

# %%
sns.barplot(x="Species",
            y = 'Length3',
            data=fish,
            estimator = sum)

# %% [markdown]
# ### 5. **Species vs Height**

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Species',y="Height",data=fish,palette='summer')

# %%
sns.barplot(x="Species",
            y = 'Height',
            data=fish,
            estimator = sum)

# %% [markdown]
# ### 6. **Species vs Width**

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Species',y="Width",data=fish,palette='summer')

# %%
sns.barplot(x="Species",
            y = 'Width',
            data=fish,
            estimator = sum)

# %% [markdown]
# ***So, we see all types of possible graphs!***

# %% [markdown]
# ***Now, as the problem sets says our dependent variable is Weight and all other variables are Independent.***
#
# ***So, let's do multiple linear regression now!***

# %% [markdown]
# ## **Multiple Linear Regression :**

# %%
fish.head()
# Out:
#   Species  Length1  Length2  Length3   Height   Width  weight_logarithm_base2
# 0   Bream     23.2     25.4     30.0  11.5200  4.0200                5.488938
# 1   Bream     24.0     26.3     31.2  12.4800  4.3056                5.669881
# 2   Bream     23.9     26.5     31.1  12.3778  4.6961                5.828946
# 3   Bream     26.3     29.0     33.5  12.7300  4.4555                5.894403
# 4   Bream     26.5     29.0     34.0  12.4440  5.1340                6.063785

# %% [markdown]
# ***As you see "Species" column is a categorical colimn. In regression analysis, we don't need any categorical columns!***
#
# ***Hence, we will drop the column!***

# %%
fish.drop("Species", axis=1, inplace= True)
fish.head()
# Out:
#    Length1  Length2  Length3   Height   Width  weight_logarithm_base2
# 0     23.2     25.4     30.0  11.5200  4.0200                5.488938
# 1     24.0     26.3     31.2  12.4800  4.3056                5.669881
# 2     23.9     26.5     31.1  12.3778  4.6961                5.828946
# 3     26.3     29.0     33.5  12.7300  4.4555                5.894403
# 4     26.5     29.0     34.0  12.4440  5.1340                6.063785

# %% [markdown]
# ***Now, as our dependent variable is "Weight", we will seperate this column from the dataset.***

# %%
fish.drop("weight_logarithm_base2", axis=1).head()
# Out:
#    Length1  Length2  Length3   Height   Width
# 0     23.2     25.4     30.0  11.5200  4.0200
# 1     24.0     26.3     31.2  12.4800  4.3056
# 2     23.9     26.5     31.1  12.3778  4.6961
# 3     26.3     29.0     33.5  12.7300  4.4555
# 4     26.5     29.0     34.0  12.4440  5.1340

# %%
fish["weight_logarithm_base2"].head()
# Out:
# 0    5.488938
# 1    5.669881
# 2    5.828946
# 3    5.894403
# 4    6.063785
# Name: weight_logarithm_base2, dtype: float64

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(fish.drop("weight_logarithm_base2", axis=1),fish["weight_logarithm_base2"], test_size =.25, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_test_int =  np.exp(y_test)
y_test_int.head()
# Out:
# 127    1000.0
# 42      120.0
# 55      270.0
# 101     218.0
# 33      975.0
# Name: weight_logarithm_base2, dtype: float64

# %%
y_pred_log = lm.predict(x_test)
y_pred_int = np.exp(y_pred_log)
y_pred_int
# Out:
# array([1467.16846798,   76.44919421,  203.25409061,  122.48976431,
#        2261.63371153, 1489.41534157,   81.18919235, 2126.43471561,
#         536.95589395,   37.79565502,  917.99426619,  118.91339073,
#          74.30687917,   76.11339566,  190.23667924,  105.22640594,
#          75.40081728,   97.70516077,  363.97586298,  247.78105042,
#        1798.64450484,  108.50259507,   83.93017474,   99.12003682,
#          20.24280009, 1652.73302646,  323.0232396 ,  240.87395802,
#          17.99619745,   30.29940492, 2126.43471561,  132.79136425,
#         143.94312965,  128.54086162,  137.83591268,  514.18131264,
#         241.94824477,  105.91690006, 1028.31104068,  234.42305614])

# %%
y_pred_log
# Out:
# array([7.29108961, 4.33662639, 5.31445687, 4.80802747, 7.72384271,
#        7.30613893, 4.39678214, 7.66220201, 6.28591596, 3.63219415,
#        6.82219114, 4.77839542, 4.30820353, 4.33222428, 5.24826898,
#        4.65611428, 4.32281811, 4.58195438, 5.89708755, 5.5125455 ,
#        7.49478861, 4.68677409, 4.4299852 , 4.59633161, 3.00779918,
#        7.41018558, 5.77772427, 5.4842738 , 2.89016048, 3.41112807,
#        7.66220201, 4.88877921, 4.96941829, 4.85624684, 4.92606394,
#        6.24257595, 5.48872384, 4.66265482, 6.93567297, 5.45712742])

# %%
y_test.head()
# Out:
# 127    6.907755
# 42     4.787492
# 55     5.598422
# 101    5.384495
# 33     6.882437
# Name: weight_logarithm_base2, dtype: float64

# %%
data_1 = {'Actual Values':y_test,
        'Predicted Values':y_pred_log}

df = pd.DataFrame(data_1)
 
# Print the output.
df.head()
# Out:
#      Actual Values  Predicted Values
# 127       6.907755          7.291090
# 42        4.787492          4.336626
# 55        5.598422          5.314457
# 101       5.384495          4.808027
# 33        6.882437          7.723843

# %%
data_2 = {'Actual Values':y_test_int,
        'Predicted Values':y_pred_int}

df = pd.DataFrame(data_2)

df.head()
# Out:
#      Actual Values  Predicted Values
# 127         1000.0       1467.168468
# 42           120.0         76.449194
# 55           270.0        203.254091
# 101          218.0        122.489764
# 33           975.0       2261.633712

# %%
lm.coef_
# Out:
# array([-0.50518351,  0.5825085 , -0.0472516 ,  0.08021296,  0.2534042 ])

# %%
lm.intercept_
# Out:
# 1.6991113750506495

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
mae = mean_absolute_error(y_pred,y_test)
mse = mean_squared_error(y_pred,y_test)
r2 = r2_score(y_test,y_pred)
print("r2 is", r2)
print("mae is", mae)
print("mse is", mse)
# Out:
# r2 is 0.8958778985290266
# mae is 0.340030006985012
# mse is 0.14485034917437017

# %%
data = {'Value':[r2, mae, mse]}
df = pd.DataFrame(data, index =['r2',
                                'mae',
                                'mse'])
df
# Out:
#         Value
# r2   0.895878
# mae  0.340030
# mse  0.144850
